# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Joseph\Desktop\Data Analysis Portfolio\world_population.csv")
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
# i want to make 'Country' the index

# %%
df = pd.read_csv(r"C:\Users\Joseph\Desktop\Data Analysis Portfolio\world_population.csv", index_col = "Country")
df
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
# ...

# %%
# now i want to reset the index

# %%
df.reset_index(inplace=True)
df
# Out:
#                Country  Rank CCA3           Capital Continent  \
# 0          Afghanistan    36  AFG             Kabul      Asia
# 1              Albania   138  ALB            Tirana    Europe
# 2              Algeria    34  DZA           Algiers    Africa
# 3       American Samoa   213  ASM         Pago Pago   Oceania
# 4              Andorra   203  AND  Andorra la Vella    Europe
# ..                 ...   ...  ...               ...       ...
# 229  Wallis and Futuna   226  WLF          Mata-Utu   Oceania
# 230     Western Sahara   172  ESH          El Aaiún    Africa
# 231              Yemen    46  YEM             Sanaa      Asia
# 232             Zambia    63  ZMB            Lusaka    Africa
# 233           Zimbabwe    74  ZWE            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
# i can also make the country index another way

# %%
df.set_index('Country', inplace = True)
df
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#                Country  Rank CCA3           Capital Continent  \
# 0          Afghanistan    36  AFG             Kabul      Asia
# 1              Albania   138  ALB            Tirana    Europe
# 2              Algeria    34  DZA           Algiers    Africa
# 3       American Samoa   213  ASM         Pago Pago   Oceania
# 4              Andorra   203  AND  Andorra la Vella    Europe
# ..                 ...   ...  ...               ...       ...
# 229  Wallis and Futuna   226  WLF          Mata-Utu   Oceania
# 230     Western Sahara   172  ESH          El Aaiún    Africa
# 231              Yemen    46  YEM             Sanaa      Asia
# 232             Zambia    63  ZMB            Lusaka    Africa
# 233           Zimbabwe    74  ZWE            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
# now i wan to have 2 indexes using Contient and Country

# %%
df.set_index(['Continent','Country'], inplace = True)
df
# Out:
#                              Rank CCA3           Capital  2022 Population  \
# Continent Country
# Asia      Afghanistan          36  AFG             Kabul       41128771.0
# Europe    Albania             138  ALB            Tirana        2842321.0
# Africa    Algeria              34  DZA           Algiers       44903225.0
# Oceania   American Samoa      213  ASM         Pago Pago          44273.0
# Europe    Andorra             203  AND  Andorra la Vella          79824.0
# ...                           ...  ...               ...              ...
# Oceania   Wallis and Futuna   226  WLF          Mata-Utu          11572.0
# Africa    Western Sahara      172  ESH          El Aaiún         575986.0
# Asia      Yemen                46  YEM             Sanaa       33696614.0
# Africa    Zambia               63  ZMB            Lusaka       20017675.0
#           Zimbabwe             74  ZWE            Harare       16320537.0
#
# ...

# %%
# i want the contient to group the countries alphabetical order

# %%
df.sort_index()
# Out:
#                             Rank CCA3      Capital  2022 Population  \
# Continent     Country
# Africa        Algeria         34  DZA      Algiers       44903225.0
#               Angola          42  AGO       Luanda       35588987.0
#               Benin           77  BEN   Porto-Novo       13352864.0
#               Botswana       144  BWA     Gaborone        2630296.0
#               Burkina Faso    58  BFA  Ouagadougou       22673762.0
# ...                          ...  ...          ...              ...
# South America Paraguay       109  PRY     Asunción        6780744.0
#               Peru            44  PER         Lima       34049588.0
#               Suriname       170  SUR   Paramaribo         618040.0
#               Uruguay        133  URY   Montevideo        3422794.0
#               Venezuela       51  VEN      Caracas       28301696.0
#
#                             2020 Population  2015 Population  2010 Population  \
# Continent     Country
# ...

# %%
# to be more specific to see all the rows information

# %%
df.sort_index()

#pd.set_option('display.max.rows', 234)
# Out:
#                             Rank CCA3      Capital  2022 Population  \
# Continent     Country
# Africa        Algeria         34  DZA      Algiers       44903225.0
#               Angola          42  AGO       Luanda       35588987.0
#               Benin           77  BEN   Porto-Novo       13352864.0
#               Botswana       144  BWA     Gaborone        2630296.0
#               Burkina Faso    58  BFA  Ouagadougou       22673762.0
# ...                          ...  ...          ...              ...
# South America Paraguay       109  PRY     Asunción        6780744.0
#               Peru            44  PER         Lima       34049588.0
#               Suriname       170  SUR   Paramaribo         618040.0
#               Uruguay        133  URY   Montevideo        3422794.0
#               Venezuela       51  VEN      Caracas       28301696.0
#
#                             2020 Population  2015 Population  2010 Population  \
# Continent     Country
# ...

# %%
# to see the opposite in ascending order

# %%
df.sort_index(ascending=False)

#pd.set_option('display.max.rows', 234)
# Out:
#                             Rank CCA3      Capital  2022 Population  \
# Continent     Country
# South America Venezuela       51  VEN      Caracas       28301696.0
#               Uruguay        133  URY   Montevideo        3422794.0
#               Suriname       170  SUR   Paramaribo         618040.0
#               Peru            44  PER         Lima       34049588.0
#               Paraguay       109  PRY     Asunción        6780744.0
# ...                          ...  ...          ...              ...
# Africa        Burkina Faso    58  BFA  Ouagadougou       22673762.0
#               Botswana       144  BWA     Gaborone        2630296.0
#               Benin           77  BEN   Porto-Novo       13352864.0
#               Angola          42  AGO       Luanda       35588987.0
#               Algeria         34  DZA      Algiers       44903225.0
#
#                             2020 Population  2015 Population  2010 Population  \
# Continent     Country
# ...

# %%
# i can also customise the filtering process to  make the contient descending and country acesnding

# %%
df.sort_index(ascending=[False, True])

#pd.set_option('display.max.rows', 234)
# Out:
#                               Rank CCA3       Capital  2022 Population  \
# Continent     Country
# South America Argentina         33  ARG  Buenos Aires       45510318.0
#               Bolivia           80  BOL         Sucre       12224110.0
#               Brazil             7  BRA      Brasilia      215313498.0
#               Chile             65  CHL      Santiago       19603733.0
#               Colombia          28  COL        Bogota       51874024.0
# ...                            ...  ...           ...              ...
# Africa        Tunisia           79  TUN         Tunis       12356117.0
#               Uganda            31  UGA       Kampala       47249585.0
#               Western Sahara   172  ESH      El Aaiún         575986.0
#               Zambia            63  ZMB        Lusaka       20017675.0
#               Zimbabwe          74  ZWE        Harare       16320537.0
#
#                               2020 Population  2015 Population  \
# Continent     Country
# ...

# %%
df.sort_index()

#pd.set_option('display.max.rows', 234)
# Out:
#                             Rank CCA3      Capital  2022 Population  \
# Continent     Country
# Africa        Algeria         34  DZA      Algiers       44903225.0
#               Angola          42  AGO       Luanda       35588987.0
#               Benin           77  BEN   Porto-Novo       13352864.0
#               Botswana       144  BWA     Gaborone        2630296.0
#               Burkina Faso    58  BFA  Ouagadougou       22673762.0
# ...                          ...  ...          ...              ...
# South America Paraguay       109  PRY     Asunción        6780744.0
#               Peru            44  PER         Lima       34049588.0
#               Suriname       170  SUR   Paramaribo         618040.0
#               Uruguay        133  URY   Montevideo        3422794.0
#               Venezuela       51  VEN      Caracas       28301696.0
#
#                             2020 Population  2015 Population  2010 Population  \
# Continent     Country
# ...

# %%
# i can now search for the first string to see africa countries attributes

# %%
df.loc['Africa']
# Out:
#                           Rank CCA3       Capital  2022 Population  \
# Country
# Algeria                     34  DZA       Algiers       44903225.0
# Angola                      42  AGO        Luanda       35588987.0
# Benin                       77  BEN    Porto-Novo       13352864.0
# Botswana                   144  BWA      Gaborone        2630296.0
# Burkina Faso                58  BFA   Ouagadougou       22673762.0
# Burundi                     78  BDI     Bujumbura       12889576.0
# Cameroon                    53  CMR       Yaounde       27914536.0
# Cape Verde                 171  CPV         Praia         593149.0
# Central African Republic   117  CAF        Bangui        5579144.0
# Chad                        69  TCD     N'Djamena       17723315.0
# Comoros                    163  COM        Moroni         836774.0
# Djibouti                   160  DJI      Djibouti        1120849.0
# DR Congo                    15  COD      Kinshasa       99010212.0
# ...

# %%
# to specify to see nigeria in africa

# %%
df.loc['Africa', 'Nigeria']
# Out:
# Rank                                     6
# CCA3                                   NGA
# Capital                              Abuja
# 2022 Population                218541212.0
# 2020 Population                208327405.0
# 2015 Population                183995785.0
# 2010 Population                160952853.0
# 2000 Population                122851984.0
# 1990 Population                 95214257.0
# 1980 Population                 72951439.0
# 1970 Population                 55569264.0
# Area (km²)                        923768.0
# Density (per km²)                 236.5759
# Growth Rate                         1.0241
# World Population Percentage           2.74
# Name: (Africa, Nigeria), dtype: object

# %%
# for North America countries attributes

# %%
df.loc['North America']
# Out:
#                                   Rank CCA3           Capital  \
# Country
# Anguilla                           224  AIA        The Valley
# Antigua and Barbuda                201  ATG      Saint John’s
# Aruba                              198  ABW        Oranjestad
# Bahamas                            176  BHS            Nassau
# Barbados                           186  BRB        Bridgetown
# Belize                             177  BLZ          Belmopan
# Bermuda                            206  BMU          Hamilton
# British Virgin Islands             221  VGB         Road Town
# Canada                              39  CAN            Ottawa
# Cayman Islands                     205  CYM       George Town
# Costa Rica                         124  CRI          San José
# Cuba                                85  CUB            Havana
# Curacao                            189  CUW        Willemstad
# Dominica                           204  DMA            Roseau
# ...

# %%
# to specify to see united state in north america

# %%
df.loc['North America', 'United States']
# Out:
# Rank                                          3
# CCA3                                        USA
# Capital                        Washington, D.C.
# 2022 Population                     338289857.0
# 2020 Population                     335942003.0
# 2015 Population                     324607776.0
# 2010 Population                     311182845.0
# 2000 Population                     282398554.0
# 1990 Population                     248083732.0
# 1980 Population                     223140018.0
# 1970 Population                     200328340.0
# Area (km²)                            9372610.0
# Density (per km²)                       36.0935
# Growth Rate                              1.0038
# World Population Percentage                4.24
# Name: (North America, United States), dtype: object
