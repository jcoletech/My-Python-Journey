# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Joseph\Desktop\Data Analysis Portfolio\Ice Cream Ratings.csv")
df
# Out:
#        Date  Flavor Rating  Texture Rating  Overall Rating
# 0  1/1/2022       0.223090        0.040220        0.600129
# 1  1/2/2022       0.635886        0.938476        0.106264
# 2  1/3/2022       0.442323        0.044154        0.598112
# 3  1/4/2022       0.389128        0.549676        0.489353
# 4  1/5/2022       0.386887        0.519439        0.988280
# 5  1/6/2022       0.877984        0.193588        0.832827
# 6  1/7/2022       0.140995        0.325110        0.105147

# %%
# i want to make my date as the index

# %%
df = pd.read_csv(r"C:\Users\Joseph\Desktop\Data Analysis Portfolio\Ice Cream Ratings.csv")
df = df.set_index('Date')
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
# Line Chart Visulazation

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# to break the plot into 3 for each ratings

# %%
df.plot(kind='line', subplots = True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# To give the line graph a title like 'ice cream rating'

# %%
df.plot(kind='line', title = 'Ice Cream Rating')
# Out:
# <Axes: title={'center': 'Ice Cream Rating'}, xlabel='Date'>

# %%
# Also decided to give my X and Y axis title

# %%
df.plot(kind='line', title = 'Ice Cream Rating', xlabel = 'Daily Ratings', ylabel = 'Scores')
# Out:
# <Axes: title={'center': 'Ice Cream Rating'}, xlabel='Daily Ratings', ylabel='Scores'>

# %%
# Bar Chart Visulazation

# %%
df.plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
# or i can decide to make it a staked bar chart

# %%
df.plot.barh(stacked = True)
# Out:
# <Axes: ylabel='Date'>

# %%
df.plot.barh(stacked = True, title = 'Ice Cream Rating', xlabel = 'Daily Ratings', ylabel = 'Scores')
# Out:
# <Axes: title={'center': 'Ice Cream Rating'}, xlabel='Daily Ratings', ylabel='Scores'>

# %%
df.plot(kind='bar', title = 'Ice Cream Rating', xlabel = 'Daily Ratings', ylabel = 'Scores')
# Out:
# <Axes: title={'center': 'Ice Cream Rating'}, xlabel='Daily Ratings', ylabel='Scores'>

# %%
# to be specific for only Flavor rating vertical chart

# %%
df['Flavor Rating'].plot(kind='bar', stacked=True, title = 'Ice Cream Rating', xlabel = 'Daily Ratings', ylabel = 'Scores')
# Out:
# <Axes: title={'center': 'Ice Cream Rating'}, xlabel='Daily Ratings', ylabel='Scores'>

# %%
# to be specific for only Flavor rating horizontal chart

# %%
df['Flavor Rating'].plot.barh(stacked=True, title = 'Ice Cream Rating', xlabel = 'Daily Ratings', ylabel = 'Scores')
# Out:
# <Axes: title={'center': 'Ice Cream Rating'}, xlabel='Daily Ratings', ylabel='Scores'>

# %%
# scattered plot  -note x and y axis have to be stated

# %%
df.plot.scatter(x = 'Texture Rating', y = 'Overall Rating')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
# i can decide to add 's to size of the dot' and 'y to change the colour'

# %%
df.plot.scatter(x = 'Texture Rating', y = 'Overall Rating', s = 280, c = 'Black')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
# Historgram --Note 'for the bins 10 is default it better when specified'

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# making specification for my bin

# %%
df.plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Box Plot Visulazation

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
# Area Plot Visulazation

# %%
df.plot.area()
# Out:
# <Axes: xlabel='Date'>

# %%
# i decided to add figsize to my area plot to make it bigger

# %%
df.plot.area(figsize = (10,5))
# Out:
# <Axes: xlabel='Date'>

# %%
# Pie Chart Visulazation --Note we need to specify what column we are working with y

# %%
df.plot.pie(y='Flavor Rating')
# Out:
# <Axes: ylabel='Flavor Rating'>

# %%
# to make the chart bigger we need to specify our figsize

# %%
df.plot.pie(y='Flavor Rating',figsize=(10,10))
# Out:
# <Axes: ylabel='Flavor Rating'>

# %%
# i can use differnt plot styles below are all the avaliable libries for visulation

# %%
print(plt.style.available)
plt.style.use('classic')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
df.plot(kind='line', title = 'Ice Cream Rating', xlabel = 'Daily Ratings', ylabel = 'Scores')
# Out:
# <Axes: title={'center': 'Ice Cream Rating'}, xlabel='Daily Ratings', ylabel='Scores'>

# %%
print(plt.style.available)
plt.style.use('dark_background')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
df.plot.area(figsize = (10,5))
# Out:
# <Axes: xlabel='Date'>

# %%
print(plt.style.available)
plt.style.use('seaborn-v0_8-deep')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
df.plot.barh(stacked = True, title = 'Ice Cream Rating', xlabel = 'Daily Ratings', ylabel = 'Scores')
# Out:
# <Axes: title={'center': 'Ice Cream Rating'}, xlabel='Daily Ratings', ylabel='Scores'>
